# %% [markdown]
# ## Raleigh Event Webscraper
# ### -Dhillon Patel

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %% [markdown]
# ### Web scraper for Goodnights Comedy Club

# %%
# URL of the Goodnights Comedy events page
url = "https://www.goodnightscomedy.com/events"

# Add crawl delay to avoid overloading website
sleep_time = 5
if type(sleep_time) == int:
    time.sleep(sleep_time)

# Make a request to fetch the webpage content
response = requests.get(url)


if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all event items on the page by targeting the 'event-list-item' class
    events = soup.find_all('div', class_='event-list-item')

    # Initialize a list to hold the extracted event details
    event_list = []

    # Loop through each event item to extract relevant details
    for event in events:

        # Extract the title of the event from the <h3> tag with the class 'el-header'
        title_element = event.find('h3', class_='el-header')

        # Extract the date and time of the event from the <h6> tag with the class 'event-date'
        # The HTML includes both date and time in the same tag
        time_element = event.find('h6', class_='event-date')

        # Extract the ticket link from an <a> tag containing the text 'Buy Tickets'
        ticket_link_element = event.find('a', string='Buy Tickets')

        # Clean and extract text or provide a default value if the element is missing
        title = title_element.text.strip() if title_element else "None Found"
        date = time_element.text.strip().split(",")[0].strip() if time_element else "None Found"  # Extract date
        time = time_element.text.strip().split(",")[1].strip() if time_element else "None Found"  # Extract time
        ticket_link = ticket_link_element['href'] if ticket_link_element else "None Found"  # Extract link

        # Append the extracted details as a dictionary to the list
        event_list.append({
            "Title": title,  # Event title
            "Date": date,    # Event date
            "Time": time,    # Event time
            # Construct the full ticket URL if it exists; otherwise, keep it as 'None'
            "Ticket Link": f"https://www.goodnightscomedy.com{ticket_link}" if ticket_link != "None Found" else ticket_link
        })

    # Convert the list of extracted event details into a pandas DataFrame
    events_df = pd.DataFrame(event_list)

    # Display the DataFrame to the user
    display(events_df)

else:
    # Print an error message if the webpage could not be fetched successfully
    print("Failed to retrieve the webpage. Please check the URL or try again later.")
# Out:
#                                                 Title             Date  \
# 0                      Special Event: Natasha Leggero       None Found
# 1   Special Event: New Year's Eve with Gabriel Rut...       None Found
# 2   Room 861 at Goodnights: New Year's Eve with Re...       None Found
# 3                     Special Event: Frankie Quiñones       None Found
# 4               Room 861 at Goodnights: James Adomian       None Found
# 5                               Special Event: Cat Ce  Wed Jan  8 2025
# 6                 Goodnights Presents: Zainab Johnson  Thu Jan  9 2025
# 7                   Room 861 at Goodnights: Joe Machi       None Found
# 8                             Special Event: DC Curry       None Found
# 9                         Special Event: Casey Rocket       None Found
# 10            Room 861 at Goodnights: Caitlin Peluffo       None Found
# 11       Goodnights Comedy Academy: Stand Up Workshop  Sun Jan 19 2025
# 12  Goodnights Presents: Calimar White aka Agent R...  Sun Jan 19 2025
# 13                 Goodnights Presents: Damon Darling  Wed Jan 22 2025
# 14                          Special Event: John Crist       None Found
# 15                 Room 861 at Goodnights: Kelly Ryan       None Found
# 16                                      Private Event  Mon Jan 27 2025
# 17                       Special Event: Jordan Jensen       None Found
# 18                  Room 861 at Goodnights: Tony Deyo       None Found
# 19                Goodnights Presents: Musical Monday  Sun Feb  2 2025
# 20                           Special Event: Chad & JT  Tue Feb  4 2025
# 21                   Goodnights Presents: Gabby Bryan  Wed Feb  5 2025
# 22                        Special Event: Kevin Nealon       None Found
# 23  Goodnights Presents: Ladies Laugh Lounge Galen...  Thu Feb 13 2025
# 24                 Goodnights Presents: Benny Feldman  Thu Feb 13 2025
# 25  Goodnights Presents: Valentine's Day with Jour...       None Found
# 26                          Special Event: Kail Lowry       None Found
# 27                          Special Event: Rhys Darby       None Found
# 28                Goodnights Presents: Geoffrey Asmus       None Found
# 29                          Special Event: Bob Marley  Sun Feb 23 2025
# 30                         Special Event: Cactus Tate  Thu Feb 27 2025
# 31               Goodnights Presents: K Trevor Wilson       None Found
# 32                        Special Event: Craig Conant       None Found
# 33  Special Event: Martin Amini - THE LOVE WORLD TOUR       None Found
# 34                 Room 861 at Goodnights: Nish Kumar  Fri Mar  7 2025
# 35                      Special Event: Peter Antoniou  Sun Mar  9 2025
# 36                      Special Event: Michael Colyar       None Found
# 37                    Special Event: Steve Hofstetter  Tue Mar 18 2025
# 38                           Special Event: Josh Blue       None Found
# 39                Room 861 at Goodnights: Jay Derrell  Sun Mar 23 2025
# 40                           Special Event: Tony Rock       None Found
# 41                       Special Event: Kam Patterson       None Found
# 42                     Special Event: Gareth Reynolds  Mon Apr 14 2025
# 43                      Goodnights Presents: Hans Kim       None Found
# 44                        Special Event: Will Burkart  Wed May 14 2025
# 45                         Special Event: Kristin Key       None Found
# 46                      Special Event: Randy Feltface       None Found
# 47         Special Event: Take It Or Leave It Podcast  Mon Oct  6 2025
# 48              Special Event: Joe "Mr. D" Dombrowski       None Found
#
#           Time                                     Ticket Link
# 0   None Found  https://www.goodnightscomedy.com/events/104690
# 1   None Found  https://www.goodnightscomedy.com/events/100750
# 2   None Found  https://www.goodnightscomedy.com/events/106166
# 3   None Found  https://www.goodnightscomedy.com/events/100793
# 4   None Found  https://www.goodnightscomedy.com/events/102003
# 5      7:15 PM   https://www.goodnightscomedy.com/shows/278619
# 6      8:00 PM   https://www.goodnightscomedy.com/shows/267654
# 7   None Found  https://www.goodnightscomedy.com/events/106323
# 8   None Found  https://www.goodnightscomedy.com/events/100796
# 9   None Found  https://www.goodnightscomedy.com/events/101744
# 10  None Found  https://www.goodnightscomedy.com/events/102643
# 11     3:00 PM   https://www.goodnightscomedy.com/shows/292647
# 12     7:00 PM   https://www.goodnightscomedy.com/shows/293074
# 13     8:00 PM   https://www.goodnightscomedy.com/shows/293409
# 14  None Found  https://www.goodnightscomedy.com/events/105206
# 15  None Found  https://www.goodnightscomedy.com/events/100960
# 16    11:59 PM   https://www.goodnightscomedy.com/shows/294314
# 17  None Found  https://www.goodnightscomedy.com/events/101366
# 18  None Found  https://www.goodnightscomedy.com/events/102628
# 19     4:30 PM   https://www.goodnightscomedy.com/shows/284284
# 20     8:00 PM   https://www.goodnightscomedy.com/shows/269847
# 21     8:00 PM   https://www.goodnightscomedy.com/shows/294305
# 22  None Found  https://www.goodnightscomedy.com/events/100866
# 23     7:30 PM   https://www.goodnightscomedy.com/shows/288047
# 24     8:00 PM   https://www.goodnightscomedy.com/shows/294470
# 25  None Found  https://www.goodnightscomedy.com/events/106236
# 26  None Found  https://www.goodnightscomedy.com/events/105350
# 27  None Found  https://www.goodnightscomedy.com/events/105351
# 28  None Found  https://www.goodnightscomedy.com/events/103216
# 29     7:00 PM   https://www.goodnightscomedy.com/shows/288083
# 30     8:00 PM   https://www.goodnightscomedy.com/shows/276425
# 31  None Found   https://www.goodnightscomedy.com/events/95190
# 32  None Found  https://www.goodnightscomedy.com/events/101462
# 33  None Found   https://www.goodnightscomedy.com/events/99165
# 34     8:00 PM   https://www.goodnightscomedy.com/shows/293174
# 35     7:00 PM   https://www.goodnightscomedy.com/shows/288100
# 36  None Found  https://www.goodnightscomedy.com/events/105354
# 37     8:00 PM   https://www.goodnightscomedy.com/shows/269871
# 38  None Found  https://www.goodnightscomedy.com/events/105357
# 39     7:30 PM   https://www.goodnightscomedy.com/shows/268092
# 40  None Found  https://www.goodnightscomedy.com/events/105359
# 41  None Found  https://www.goodnightscomedy.com/events/103833
# 42     7:15 PM   https://www.goodnightscomedy.com/shows/292271
# 43  None Found  https://www.goodnightscomedy.com/events/105361
# 44     8:00 PM   https://www.goodnightscomedy.com/shows/290152
# 45  None Found  https://www.goodnightscomedy.com/events/104910
# 46  None Found  https://www.goodnightscomedy.com/events/105650
# 47     8:00 PM   https://www.goodnightscomedy.com/shows/286556
# 48  None Found  https://www.goodnightscomedy.com/events/102639

# %% [markdown]
# ### Web scraper for Lenovo Center

# %%
import time
# URL of the Lenovo Center events page
url2 = "https://www.lenovocenter.com/events"

# Add crawl delay to avoid overloading website
sleep_time = 5
if type(sleep_time) == int:
    time.sleep(sleep_time)

# Make a request to fetch the webpage content
response2 = requests.get(url2)


if response2.status_code == 200:
    soup2 = BeautifulSoup(response2.content, 'html.parser')

    # Find all event items on the page by targeting the class 'eventItem'
    events2 = soup2.find_all('div', class_='eventItem')

    # Initialize a list to hold the extracted event details
    event_list2 = []

    # Loop through each event item to extract relevant details
    for event2 in events2:

        # Extract the event title by finding the <h3> tag with the class 'title'
        title = event2.find('h3', class_='title').text.strip()

        # Extract the event date by finding the <span> tag with the class 'm-date__singleDate'
        date = event2.find('span', class_='m-date__singleDate').text.strip()

        # Extract the event time from the <h5> tag with the class 'time'
        time_element = event2.find('h5', class_='time')  # Find the time element
        time = time_element.text.strip().split("  ")[1].strip()  # Clean and split text to extract time

        # Extract the ticket link from the <a> tag with the class 'more'
        link = event2.find('a', class_='more')['href']

        # Append the extracted details as a dictionary to the list
        event_list2.append({
            "Title": title,          # Event title
            "Date": date,            # Event date
            "Time": time,            # Event time
            "Ticket Link": link      # Link to buy tickets
        })

    # Convert the list of extracted event details into a pandas DataFrame for easier manipulation
    events_df2 = pd.DataFrame(event_list2)

    # Display the DataFrame to the user
    display(events_df2)

else:
    # Print an error message if the webpage could not be fetched successfully
    print("Failed to retrieve the webpage. Please check the URL or try again later.")
# Out:
#                                             Title           Date     Time  \
# 0       New Jersey Devils vs. Carolina Hurricanes  Dec 28 / 2024  7:00 PM
# 1          Minnesota Wild vs. Carolina Hurricanes  Jan 04 / 2025  7:00 PM
# 2     Pittsburgh Penguins vs. Carolina Hurricanes  Jan 05 / 2025  6:00 PM
# 3                         Notre Dame vs. NC State  Jan 08 / 2025  7:00 PM
# 4     Toronto Maple Leafs vs. Carolina Hurricanes  Jan 09 / 2025  7:30 PM
# 5       Vancouver Canucks vs. Carolina Hurricanes  Jan 10 / 2025  7:00 PM
# 6                     North Carolina vs. NC State  Jan 11 / 2025  4:00 PM
# 7           Anaheim Ducks vs. Carolina Hurricanes  Jan 12 / 2025  5:00 PM
# 8                     2025 Hurricanes Alumni Game  Jan 13 / 2025  7:00 PM
# 9    Vegas Golden Knights vs. Carolina Hurricanes  Jan 17 / 2025  7:00 PM
# 10                        California vs. NC State  Jan 18 / 2025  6:00 PM
# 11  Columbus Blue Jackets vs. Carolina Hurricanes  Jan 23 / 2025  7:00 PM
#
#                                           Ticket Link
# 0   https://www.lenovocenter.com/events/detail/new...
# 1   https://www.lenovocenter.com/events/detail/min...
# 2   https://www.lenovocenter.com/events/detail/pit...
# 3   https://www.lenovocenter.com/events/detail/not...
# 4   https://www.lenovocenter.com/events/detail/tor...
# 5   https://www.lenovocenter.com/events/detail/van...
# 6   https://www.lenovocenter.com/events/detail/nor...
# 7   https://www.lenovocenter.com/events/detail/ana...
# 8   https://www.lenovocenter.com/events/detail/202...
# 9   https://www.lenovocenter.com/events/detail/veg...
# 10  https://www.lenovocenter.com/events/detail/cal...
# 11  https://www.lenovocenter.com/events/detail/col...

# %% [markdown]
# ### Web scraper for Coastal Credit Union Music Park

# %%
import time
# URL of the site
url3 = "https://www.coastalcreditunionmusicpark.com/shows"

# Add crawl delay to avoid overloading website
sleep_time = 5
if type(sleep_time) == int:
    time.sleep(sleep_time)


response3 = requests.get(url3)
soup3 = BeautifulSoup(response3.text, 'html.parser')


if response3.status_code == 200:
    # Find all event cards on the page targeting the class 'chakra-card css-1jq78gh'
    events3 = soup3.find_all('div', class_='chakra-card css-1jq78gh')
    event_list3 = []  # Initialize an empty list to store event details

    # Loop through each event card to extract the relevant content
    for event3 in events3:

        # Add a 5-second delay before processing each event
        time.sleep(5)

        # Extract the name of the event
        name3 = event3.find('p', class_='chakra-text css-zvlevn').string

        # Extract the date of the event
        date3 = event3.find('p', class_='chakra-text css-l141uf').string

        # Extract the ticket link for the event
        ticket_link3 = event3.find('a', string='Buy Tickets')['href']

        # Placeholder for time extraction, update the class name when known
        time_element3 = event3.find('', class_="")  # No time class specified

        # Append the extracted details as a dictionary to the list
        event_list3.append({
            "Title": name3,          # Event title
            "Date": date3,           # Event date
            "Time": time_element3,   # Event time (currently not specified)
            "Ticket Link": ticket_link3  # Link to buy tickets
        })

    # Convert the list of events into a pandas DataFrame for easier manipulation and analysis
    events_df3 = pd.DataFrame(event_list3)

    # Display the DataFrame to the user
    display(events_df3)
else:
    # Print an error message if the request failed
    print("Failed to retrieve the webpage. Please check the URL or try again later.")
# Out:
#                                                Title              Date  Time  \
# 0                        Tyler Childers: On The Road  Tue Apr 15, 2025  None
# 1       RÜFÜS DU SOL Inhale / Exhale World Tour 2025   Fri May 9, 2025  None
# 2             Keith Urban: High and Alive World Tour  Sat May 31, 2025  None
# 3               Riley Green: Damn Country Music Tour  Sat Jun 14, 2025  None
# 4                   Avril Lavigne: The Greatest Hits  Tue Jun 17, 2025  None
# 5                         Rod Stewart: One Last Time   Tue Jul 8, 2025  None
# 6  Styx & Kevin Cronin + Don Felder The Brotherho...   Wed Jul 9, 2025  None
# 7            Thomas Rhett: Better In Boots Tour 2025  Thu Jul 31, 2025  None
# 8  Nelly with Ja Rule, Eve and Special Guests: Wh...  Sat Sep 13, 2025  None
# 9              2025 Premium Season Tickets Wait List  Wed Dec 31, 2025  None
#
#                                          Ticket Link
# 0  https://concerts.livenation.com/tyler-childers...
# 1  https://concerts.livenation.com/rufus-du-sol-i...
# 2  https://concerts.livenation.com/keith-urban-hi...
# 3  https://concerts.livenation.com/riley-green-da...
# 4  https://concerts.livenation.com/avril-lavigne-...
# 5  https://concerts.livenation.com/rod-stewart-on...
# 6  https://concerts.livenation.com/styx-kevin-cro...
# 7  https://concerts.livenation.com/thomas-rhett-b...
# 8  https://concerts.livenation.com/nelly-with-ja-...
# 9  https://premium.livenation.com/venue/coastal-c...

# %% [markdown]
# ### Concatenated Dataframe with the 3 websites.

# %%
allevents = pd.concat([events_df, events_df2, events_df3], ignore_index=True)

# Display the combined DataFrame
display(allevents)
allevents.to_csv('Events.csv')
# Out:
#                                                 Title              Date  \
# 0                      Special Event: Natasha Leggero        None Found
# 1   Special Event: New Year's Eve with Gabriel Rut...        None Found
# 2   Room 861 at Goodnights: New Year's Eve with Re...        None Found
# 3                     Special Event: Frankie Quiñones        None Found
# 4               Room 861 at Goodnights: James Adomian        None Found
# ..                                                ...               ...
# 66                         Rod Stewart: One Last Time   Tue Jul 8, 2025
# 67  Styx & Kevin Cronin + Don Felder The Brotherho...   Wed Jul 9, 2025
# 68            Thomas Rhett: Better In Boots Tour 2025  Thu Jul 31, 2025
# 69  Nelly with Ja Rule, Eve and Special Guests: Wh...  Sat Sep 13, 2025
# 70              2025 Premium Season Tickets Wait List  Wed Dec 31, 2025
#
#           Time                                        Ticket Link
# 0   None Found     https://www.goodnightscomedy.com/events/104690
# 1   None Found     https://www.goodnightscomedy.com/events/100750
# 2   None Found     https://www.goodnightscomedy.com/events/106166
# 3   None Found     https://www.goodnightscomedy.com/events/100793
# 4   None Found     https://www.goodnightscomedy.com/events/102003
# ..         ...                                                ...
# 66        None  https://concerts.livenation.com/rod-stewart-on...
# 67        None  https://concerts.livenation.com/styx-kevin-cro...
# 68        None  https://concerts.livenation.com/thomas-rhett-b...
# 69        None  https://concerts.livenation.com/nelly-with-ja-...
# 70        None  https://premium.livenation.com/venue/coastal-c...
#
# [71 rows x 4 columns]
